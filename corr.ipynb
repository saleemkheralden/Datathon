# %%
from datetime import datetime as dt
# from sklearn.tree import DecisionTreeRegressor as dtr
# from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

url='https://drive.google.com/file/d/1-4YpXkd2kIOM5viSRw8g7oOQm8sicciB/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
y_train = pd.read_csv(url, index_col=0)

url='https://drive.google.com/file/d/1-7VK3dNry2-AYnfRsxMWsOKhHHMTN_ZA/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
test_indices = pd.read_csv(url, index_col=0)

# %%
corr_matrix = y_train.corr()
corr_matrix = corr_matrix.fillna(0)
for i in range(188):
    corr_matrix.iloc[i, i] = 0

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12, 12)
ax.imshow(corr_matrix, cmap="hot")
plt.show()

# %%
cor_mat_stats = corr_matrix.describe()
cMax = cor_mat_stats.loc[["max"]].transpose()
cMax[(cMax["max"] >= 0.7)]
# Out:
#                            max
# אבטיחים_מחוז תל אביב  0.999999
# חסה_מחוז ירושלים      0.804051
# צנון_יהודה ושומרון    0.804051
# קולורבי_מחוז ירושלים  0.999999

# %%
cor_mat_stats
# Out:
#        other_יהודה ושומרון  other_מחוז הדרום  other_מחוז המרכז  \
# count           188.000000        188.000000        188.000000
# mean              0.006676          0.030681          0.005667
# std               0.061505          0.075233          0.046844
# min              -0.030387         -0.087095         -0.062242
# 25%              -0.011896         -0.022646         -0.022995
# 50%              -0.005550          0.005757         -0.009352
# 75%               0.000656          0.061772          0.022720
# max               0.563320          0.315868          0.235818
#
#        other_מחוז הצפון  other_מחוז חיפה  other_מחוז ירושלים  \
# count        188.000000       188.000000          188.000000
# mean          -0.003852         0.009320           -0.005509
# std            0.074171         0.046736            0.018503
# min           -0.136505        -0.061032           -0.031255
# 25%           -0.042594        -0.018818           -0.012252
# 50%           -0.018795        -0.007008           -0.006487
# 75%            0.007365         0.021681           -0.003021
# max            0.430283         0.235818            0.181978
#
#        other_מחוז תל אביב  אבטיחים_other  אבטיחים_יהודה ושומרון  \
# count          188.000000     188.000000             188.000000
# mean            -0.001131       0.004235               0.007523
# std              0.042494       0.052038               0.058425
# min             -0.039567      -0.066771              -0.027684
# 25%             -0.017314      -0.018748              -0.009360
# 50%             -0.008302      -0.008365              -0.004332
# 75%             -0.002074       0.005110              -0.001912
# max              0.371161       0.409690               0.445579
#
#        אבטיחים_מחוז הדרום  ...  תפוזים_מחוז המרכז  תפוזים_מחוז הצפון  \
# count          188.000000  ...         188.000000         188.000000
# mean             0.003885  ...           0.013086          -0.004584
# std              0.066766  ...           0.069420           0.032048
# min             -0.082158  ...          -0.086757          -0.058500
# 25%             -0.026425  ...          -0.023628          -0.019049
# 50%             -0.012974  ...          -0.011406          -0.009975
# 75%              0.000299  ...           0.022311           0.000000
# max              0.373452  ...           0.290121           0.150288
#
#        תפוזים_מחוז חיפה  תפוזים_מחוז תל אביב  תפוחים_other  תפוחים_מחוז הדרום  \
# count        188.000000           188.000000    188.000000         188.000000
# mean           0.008008             0.022208     -0.015301           0.008838
# std            0.057430             0.071484      0.051144           0.072125
# min           -0.043336            -0.079498     -0.113107          -0.066807
# 25%           -0.014374            -0.016433     -0.042590          -0.020922
# 50%           -0.006333            -0.003498     -0.021820          -0.009800
# 75%            0.001558             0.047511     -0.002839           0.000000
# max            0.476005             0.484865      0.225460           0.437390
#
#        תפוחים_מחוז המרכז  תפוחים_מחוז הצפון  תפוחים_מחוז חיפה  \
# count         188.000000         188.000000        188.000000
# mean            0.008308          -0.011050          0.006106
# std             0.074874           0.050208          0.069571
# min            -0.060932          -0.088343         -0.062200
# 25%            -0.016817          -0.036669         -0.014680
# 50%            -0.008462          -0.019054         -0.007120
# 75%             0.009554          -0.006292          0.000460
# max             0.660666           0.254160          0.660666
#
#        תפוחים_מחוז תל אביב
# count           188.000000
# mean              0.005169
# std               0.057707
# min              -0.028474
# 25%              -0.008828
# 50%              -0.004267
# 75%              -0.001914
# max               0.426626
#
# [8 rows x 188 columns]

# %% [markdown]
# חסה_מחוז ירושלים,0.804051
# צנון_יהודה ושומרון,0.804051
#
# אבטיחים_מחוז תל אביב,0.999999
# קולורבי_מחוז ירושלים,0.999999

# %%
url='https://drive.google.com/file/d/1-07zZ5oLAJZDck0WLMGVONV62jgTtxzZ/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
unprocessed_data_train = pd.read_csv(url, index_col=0)
